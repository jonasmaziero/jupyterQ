# %%
# %run init.ipynb

# %% [markdown]
# # Entanglement swapping
#
# ## Pure states
# Let's consider three labs, where are Alice, Bob, and Charlie, respectively. Two pure states $$|\xi\rangle_{AB}=\sqrt{p}|00\rangle_{AB}+\sqrt{1-p}|11\rangle_{AB}$$ and $$|\eta\rangle_{CD}=\sqrt{q}|00\rangle_{CD}+\sqrt{1-q}|11\rangle_{CD}$$ are prepared, by someone. The quantons B and C are sent to Charlie, who makes a selective Bell basis measurement (BBM) on them. The quanton A is sent to Alice and the quanton D is sent to Bob. A the end of the protocol, A and D, that have never met before, can get entangled. Let's do the math for the states:
# \begin{align}
# |\xi\rangle_{AB}\otimes|\eta\rangle_{CD} &= \big(\sqrt{p}|00\rangle_{AB}+\sqrt{1-p}|11\rangle_{AB}\big)\otimes\big(\sqrt{q}|00\rangle_{CD}+\sqrt{1-q}|11\rangle_{CD}\big) \\
# & = \sqrt{pq}|0000\rangle_{ABCD} + \sqrt{p(1-q)}|0011\rangle_{ABCD} + \sqrt{(1-p)q}|1100\rangle_{ABCD} + \sqrt{(1-p)(1-q)}|1111\rangle_{ABCD} \\
# & = \sqrt{pq}|0\rangle_{A}\frac{1}{\sqrt{2}}\big(|\Phi_{+}\rangle+|\Phi_{-}\rangle\big)_{BC}|0\rangle_{D} + \sqrt{p(1-q)}|0\rangle_{A}\frac{1}{\sqrt{2}}\big(|\Psi_{+}\rangle+|\Psi_{-}\rangle \big)_{BC}|1\rangle_{D} \\
# & \hspace{0.5cm} + \sqrt{(1-p)q}|1\rangle_{A}\frac{1}{\sqrt{2}}\big(|\Psi_{+}\rangle-|\Psi_{-}\rangle\big)_{BC}|0\rangle_{D} + \sqrt{(1-p)(1-q)}|1\rangle_{A}\frac{1}{\sqrt{2}}\big(|\Phi_{+}\rangle-|\Phi_{-}\rangle\big)_{BC}|1\rangle_{D} \\
# & = |\Phi_{+}\rangle_{BC}\frac{1}{\sqrt{2}}\big(\sqrt{pq}|00\rangle_{AD}+\sqrt{(1-p)(1-q)}|11\rangle_{AD}\big) +  |\Phi_{-}\rangle_{BC}\frac{1}{\sqrt{2}}\big(\sqrt{pq}|00\rangle_{AD}-\sqrt{(1-p)(1-q)}|11\rangle_{AD}\big) \\
# & \hspace{0.5cm} + |\Psi_{+}\rangle_{BC}\frac{1}{\sqrt{2}}\big(\sqrt{p(1-q)}|01\rangle_{AD}+\sqrt{(1-p)q}|10\rangle_{AD}\big) + |\Psi_{-}\rangle_{BC}\frac{1}{\sqrt{2}}\big(\sqrt{p(1-q)}|01\rangle_{AD}-\sqrt{(1-p)q}|10\rangle_{AD}\big).
# \end{align}

# %% [markdown]
# Above we use the relation between the computational and Bell bases:
# \begin{equation}
# \begin{cases} |\Phi_{+}\rangle = \frac{1}{\sqrt{2}}\big(|00\rangle+|11\rangle\big) \\ |\Phi_{-}\rangle = \frac{1}{\sqrt{2}}\big(|00\rangle-|11\rangle\big) \\ |\Psi_{+}\rangle = \frac{1}{\sqrt{2}}\big(|01\rangle+|10\rangle \big) \\ |\Psi_{-}\rangle = \frac{1}{\sqrt{2}}\big(|01\rangle-|10\rangle\big) \end{cases} \therefore
# \begin{cases} |00\rangle = \frac{1}{\sqrt{2}}\big(|\Phi_{+}\rangle+|\Phi_{-}\rangle\big) \\ |11\rangle = \frac{1}{\sqrt{2}}\big(|\Phi_{+}\rangle-|\Phi_{-}\rangle\big) \\ |01\rangle = \frac{1}{\sqrt{2}}\big(|\Psi_{+}\rangle+|\Psi_{-}\rangle \big) \\ |10\rangle = \frac{1}{\sqrt{2}}\big(|\Psi_{+}\rangle-|\Psi_{-}\rangle\big) \end{cases}.
# \end{equation}
#
# Post-measurement states:
# \begin{equation}
# \begin{cases} |\Phi_{\pm}\rangle_{BC} \Rightarrow |\phi_{\pm}\rangle_{AD} = \frac{1}{\sqrt{2}}\big(\sqrt{pq}|00\rangle_{AD}\pm\sqrt{(1-p)(1-q)}|11\rangle_{AD}\big) \therefore \langle\phi_{\pm}|\phi_{\pm}\rangle=\frac{1}{2}(pq+(1-p)(1-q)), \\
# |\Psi_{\pm}\rangle_{BC} \Rightarrow |\psi_{\pm}\rangle_{AD} = \frac{1}{\sqrt{2}}\big(\sqrt{p(1-q)}|01\rangle_{AD}\pm\sqrt{(1-p)q}|10\rangle_{AD}\big) \therefore \langle\psi_{\pm}|\psi_{\pm}\rangle=\frac{1}{2}(p(1-q)+(1-p)q). \end{cases}
# \end{equation}
#
# Normalized post-measurement states:
# \begin{equation}
# \begin{cases} |\Phi_{\pm}\rangle_{BC} \Rightarrow |\hat{\phi}_{\pm}\rangle_{AD} = \big(\sqrt{pq}|00\rangle_{AD}\pm\sqrt{(1-p)(1-q)}|11\rangle_{AD}\big)/\sqrt{pq+(1-p)(1-q)}, \\
# |\Psi_{\pm}\rangle_{BC} \Rightarrow |\hat{\psi}_{\pm}\rangle_{AD} = \big(\sqrt{p(1-q)}|01\rangle_{AD}\pm\sqrt{(1-p)q}|10\rangle_{AD}\big)/\sqrt{p(1-q)+(1-p)q}. \end{cases}
# \end{equation}

# %% [markdown]
# It is easy to see that if we set $p=q=1/2$, the probability of any of the BBM outcomes is 1/4 and the quantons A and D end up in a Bell (maximally entangle) state.
#
# In the geral case, let's recall that for a bipartite pure state $|\Phi\rangle=\alpha_{00}|00\rangle+\alpha_{01}|01\rangle+\alpha_{10}|10\rangle+\alpha_{11}|11\rangle$ the entanglement concurrence can be written as
# $$E_{con}(|\Phi\rangle)=|\langle\Phi|\sigma_{y}\otimes\sigma_{y}|\Phi^{*}\rangle|=2|\alpha_{00}\alpha_{11}-\alpha_{01}\alpha_{10}|.$$
# So, for the protocol above, we shall have
# \begin{equation}
# \begin{cases} |\Phi_{\pm}\rangle_{BC} \Rightarrow E_{conc}(|\hat{\phi}_{\pm}\rangle_{AD}) = 2|\pm\sqrt{pq(1-p)(1-q)}/(pq+(1-p)(1-q))-0| = 2\sqrt{p(1-p)q(1-q)}/(pq+(1-p)(1-q)), \\
# |\Psi_{\pm}\rangle_{BC} \Rightarrow E_{conc}(|\hat{\psi}_{\pm}\rangle_{AD}) = 2|0\mp\sqrt{p(1-q)q(1-p)}/(p(1-q)+(1-p)q)| = 2\sqrt{p(1-p)q(1-q)}/(p(1-q)+(1-p)q). \end{cases}
# \end{equation}
# Below are shown plots of the entanglement of AD.

# %%
def E_Phi(p,q):
    return 2*sqrt(p*(1-p)*q*(1-q))/(p*q+(1-p)*(1-q))
def E_Psi(p,q):
    return 2*sqrt(p*(1-p)*q*(1-q))/(p*(1-q)+(1-p)*q)

# %%
p = np.zeros(101)
Eq0 = np.zeros(101); Eq001 = np.zeros(101); Eq005 = np.zeros(101); Eq025 = np.zeros(101); Eq05 = np.zeros(101)
Eq0 = np.zeros(101); Eq099 = np.zeros(101); Eq095 = np.zeros(101); Eq075 = np.zeros(101)
for j in range(0,101):
    p[j] = j*0.01
    if p[j] != 0 and p[j] != 1:
        q = 0.0; Eq0[j] = E_Phi(p[j],q); q = 0.01; Eq001[j] = E_Phi(p[j],q); q = 0.05; Eq005[j] = E_Phi(p[j],q)
        q = 0.25; Eq025[j] = E_Phi(p[j],q); q = 0.5; Eq05[j] = E_Phi(p[j],q)
        q = 0.75; Eq075[j] = E_Phi(p[j],q); q = 0.95; Eq095[j] = E_Phi(p[j],q); q = 0.99; Eq099[j] = E_Phi(p[j],q)
    else:
        E[j] = 0
plt.plot(p,Eq0); plt.plot(p,Eq001); plt.plot(p,Eq005); plt.plot(p,Eq025); plt.plot(p,Eq05)
plt.plot(p,Eq075); plt.plot(p,Eq095); plt.plot(p,Eq099)
plt.xlabel('p'); plt.ylabel('E')
plt.legend(('q=0','q=0.01','q=0.05','q=0.25','q=0.5','q=0.75','q=0.95','q=0.99'))
plt.show()

# %%
p = np.zeros(101)
Eq0 = np.zeros(101); Eq001 = np.zeros(101); Eq005 = np.zeros(101); Eq025 = np.zeros(101); Eq05 = np.zeros(101)
Eq1 = np.zeros(101); Eq099 = np.zeros(101); Eq095 = np.zeros(101); Eq075 = np.zeros(101)
for j in range(0,101):
    p[j] = j*0.01
    if p[j] != 0 and p[j] != 1:
        q = 0.0; Eq0[j] = E_Psi(p[j],q); q = 0.01; Eq001[j] = E_Psi(p[j],q); q = 0.05; Eq005[j] = E_Psi(p[j],q)
        q = 0.25; Eq025[j] = E_Psi(p[j],q); q = 0.5; Eq05[j] = E_Psi(p[j],q); q = 0.75; Eq075[j] = E_Psi(p[j],q)
        q = 0.95; Eq095[j] = E_Psi(p[j],q); q = 0.99; Eq099[j] = E_Psi(p[j],q); q = 1; Eq1[j] = E_Psi(p[j],q)
    else:
        E[j] = 0
plt.plot(p,Eq0); plt.plot(p,Eq001); plt.plot(p,Eq005); plt.plot(p,Eq025); plt.plot(p,Eq05)
plt.plot(p,Eq075); plt.plot(p,Eq095); plt.plot(p,Eq099); plt.plot(p,Eq1)
plt.xlabel('p'); plt.ylabel('E')
plt.legend(('q=0','q=0.01','q=0.05','q=0.25','q=0.5','q=0.75','q=0.95','q=0.99','q=1'))
plt.show()

# %% [markdown]
# It seems that, for $q\ne0$ and $q\ne1$, for any value of $q$ we would have a value of $p$ (with $p\ne0$ and $p\ne1$) for which the quantons AD end up maximally entangled. This is interesting once the quantons BC are also maximally entangled, by the BBM. So, always there is a pair $(p',q')$ for which, at the end of the protocol, $$E(BC)+E(AD)=1+1=2.$$ It's natural  questioning if the corresponding entanglements before the protocol does also sum to one, i.e.,
# $$E(|\xi\rangle_{AB})+E(|\eta\rangle_{CD}) = 2\sqrt{p'(1-p')}+2\sqrt{q'(1-q')}=2?$$
# For $q=q'$ fixed, below we obtain the optimal $p=p',$ which leads to maximum final entanglement.

# %%
E_Phi(p,q), E_Psi(p,q)
# Out:
# ⎛    _____________________      _____________________⎞
# ⎜2⋅╲╱ p⋅q⋅(1 - p)⋅(1 - q)   2⋅╲╱ p⋅q⋅(1 - p)⋅(1 - q) ⎟
# ⎜─────────────────────────, ─────────────────────────⎟
# ⎝  p⋅q + (1 - p)⋅(1 - q)      p⋅(1 - q) + q⋅(1 - p)  ⎠

# %%
p,q = symbols('p q'); factor(diff(E_Phi(p,q),p)), factor(diff(E_Psi(p,q),p))
# Out:
# ⎛  _____________________                _____________________        ⎞
# ⎜╲╱ p⋅q⋅(p - 1)⋅(q - 1) ⋅(p + q - 1)  ╲╱ p⋅q⋅(p - 1)⋅(q - 1) ⋅(p - q)⎟
# ⎜───────────────────────────────────, ───────────────────────────────⎟
# ⎜                                2                                2  ⎟
# ⎝   p⋅(p - 1)⋅(2⋅p⋅q - p - q + 1)        p⋅(p - 1)⋅(2⋅p⋅q - p - q)   ⎠

# %% [markdown]
# We see from these expressions that maximum for the entanglement are obtained for
# \begin{equation}
# \begin{cases}
# |\Phi_{\pm}\rangle \Rightarrow p'=1-q', \\
# |\Psi_{\pm}\rangle \Rightarrow p'=q'.
# \end{cases}
# \end{equation}
#
# So, for all possible BBM outcomes, once fixed a given $q'$, the initial entanglement corresponding to the maximum final entanglement is
# \begin{align}
# E(|\xi\rangle_{AB})+E(|\eta\rangle_{CD}) & = 2\sqrt{(1-q')(1-(1-q'))} + 2\sqrt{q'(1-q')} = 4\sqrt{q'(1-q')} \\
# & = 2E(|\eta\rangle_{CD}) \ne 2,
# \end{align}
# in general (for $q'\ne 1/2$).

# %%
E_Phi(1-q,q), E_Psi(q,q),
# Out:
# ⎛   _____________     _____________⎞
# ⎜  ╱  2        2     ╱  2        2 ⎟
# ⎜╲╱  q ⋅(1 - q)    ╲╱  q ⋅(1 - q)  ⎟
# ⎜────────────────, ────────────────⎟
# ⎝   q⋅(1 - q)         q⋅(1 - q)    ⎠
